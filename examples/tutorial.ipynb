# %% [markdown]
# <div align="center">
#
#   <a href="https://ultralytics.com/yolo" target="_blank">
#     <img width="1024", src="https://raw.githubusercontent.com/ultralytics/assets/main/yolov8/banner-yolov8.png"></a>
#
#   [中文](https://docs.ultralytics.com/zh/) | [한국어](https://docs.ultralytics.com/ko/) | [日本語](https://docs.ultralytics.com/ja/) | [Русский](https://docs.ultralytics.com/ru/) | [Deutsch](https://docs.ultralytics.com/de/) | [Français](https://docs.ultralytics.com/fr/) | [Español](https://docs.ultralytics.com/es/) | [Português](https://docs.ultralytics.com/pt/) | [Türkçe](https://docs.ultralytics.com/tr/) | [Tiếng Việt](https://docs.ultralytics.com/vi/) | [العربية](https://docs.ultralytics.com/ar/)
#
#   <a href="https://github.com/ultralytics/ultralytics/actions/workflows/ci.yml"><img src="https://github.com/ultralytics/ultralytics/actions/workflows/ci.yml/badge.svg" alt="Ultralytics CI"></a>
#   <a href="https://console.paperspace.com/github/ultralytics/ultralytics"><img src="https://assets.paperspace.io/img/gradient-badge.svg" alt="Run on Gradient"/></a>
#   <a href="https://colab.research.google.com/github/ultralytics/ultralytics/blob/main/examples/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#   <a href="https://www.kaggle.com/models/ultralytics/yolo11"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
#
#   <a href="https://ultralytics.com/discord"><img alt="Discord" src="https://img.shields.io/discord/1089800235347353640?logo=discord&logoColor=white&label=Discord&color=blue"></a>
#   <a href="https://community.ultralytics.com"><img alt="Ultralytics Forums" src="https://img.shields.io/discourse/users?server=https%3A%2F%2Fcommunity.ultralytics.com&logo=discourse&label=Forums&color=blue"></a>
#   <a href="https://reddit.com/r/ultralytics"><img alt="Ultralytics Reddit" src="https://img.shields.io/reddit/subreddit-subscribers/ultralytics?style=flat&logo=reddit&logoColor=white&label=Reddit&color=blue"></a>
#
# Welcome to the Ultralytics YOLO11 🚀 notebook! <a href="https://github.com/ultralytics/ultralytics">YOLO11</a> is the latest version of the YOLO (You Only Look Once) AI models developed by <a href="https://ultralytics.com">Ultralytics</a>. This notebook serves as the starting point for exploring the various resources available to help you get started with YOLO11 and understand its features and capabilities.
#
# YOLO11 models are fast, accurate, and easy to use, making them ideal for various object detection and image segmentation tasks. They can be trained on large datasets and run on diverse hardware platforms, from CPUs to GPUs.
#
# We hope that the resources in this notebook will help you get the most out of YOLO11. Please browse the YOLO11 <a href="https://docs.ultralytics.com/">Docs</a> for details, raise an issue on <a href="https://github.com/ultralytics/ultralytics">GitHub</a> for support, and join our <a href="https://ultralytics.com/discord">Discord</a> community for questions and discussions!
#
#   <a href="https://www.youtube.com/watch?v=ZN3nRZT7b24" target="_blank">
#     <img src="https://img.youtube.com/vi/ZN3nRZT7b24/maxresdefault.jpg" alt="Ultralytics Video" width="720" style="border-radius: 10px; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2);"></a>
#
#   <p style="font-size: 16px; font-family: Arial, sans-serif; color: #555;">
#     <strong>Watch: </strong> How to Train
#   <a href="https://github.com/ultralytics/ultralytics">Ultralytics</a>
#   <a href="https://docs.ultralytics.com/models/yolo11/">YOLO11</a> Model on Custom Dataset using Google Colab Notebook 🚀</p>
# </div>

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.67-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.20.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.55.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2024.12.14)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.67-py3-none-any.whl (913 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 913.5/913.5 kB 41.4 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.67 ultralytics-thop-2.0.14

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/dataset/dataset.zip -d /content/dataset
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers10.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers100.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1000.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1001.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1002.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1003.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1005.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1006.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1007.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1009.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers101.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1010.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1011.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1013.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1015.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1016.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1017.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1019.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers102.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1021.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1022.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1024.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1025.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1026.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1028.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1029.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers103.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1030.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1031.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1032.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1033.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1034.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1035.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1037.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1039.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1040.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1041.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1042.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1044.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1045.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1046.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1047.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1048.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1049.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers105.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1050.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1051.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1053.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1054.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1055.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1057.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1058.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1061.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1062.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1063.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1064.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1065.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1066.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1067.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1068.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1070.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1071.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1072.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1074.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1075.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1076.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1078.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers108.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1080.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1082.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1085.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1086.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1087.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1089.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers109.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1090.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1091.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1092.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1094.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1095.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1097.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1098.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1099.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers11.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers110.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1100.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1101.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1102.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1103.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1104.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1106.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1108.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1109.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers111.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1110.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1111.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1112.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1113.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1114.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1115.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1117.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers112.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1120.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1121.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1123.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1124.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1125.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1126.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1128.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1129.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers113.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1130.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1134.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1135.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1136.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1137.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1138.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers114.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1140.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1141.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1142.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1143.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1144.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1145.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1146.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1147.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1148.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers115.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1150.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1151.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1152.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1153.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1154.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1156.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1158.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers116.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1160.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1161.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1162.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1164.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1165.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1166.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1167.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1168.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1169.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers117.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1171.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1172.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1175.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1176.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1178.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1179.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers118.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1181.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1182.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1183.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1184.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1185.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1186.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1188.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1189.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers119.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1191.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1192.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1193.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1196.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1198.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1199.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers12.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers120.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1200.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1203.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1205.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1206.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1208.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1209.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers121.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1210.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1214.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1215.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1216.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1217.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1218.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1219.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers122.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1221.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1222.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1225.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1227.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1228.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1229.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers123.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1230.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1231.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1232.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1233.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1234.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1235.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1236.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1237.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1238.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1239.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers124.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1240.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1241.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1242.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1243.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1245.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1246.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1247.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1248.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers125.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1250.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1251.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1253.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1254.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1255.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1257.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1258.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1260.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1261.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1262.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1263.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1267.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1268.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1269.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers127.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1270.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1271.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1272.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1273.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1274.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1276.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1277.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1278.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1279.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers128.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1280.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1282.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1283.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1285.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1286.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1287.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1289.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers129.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1290.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1291.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1292.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1293.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1294.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1295.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1296.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1297.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1299.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers13.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers130.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1300.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1301.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1302.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1303.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1304.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1305.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1306.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1307.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1308.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1309.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers131.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1310.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1311.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1314.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1315.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1317.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1318.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1319.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers132.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1320.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1321.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1322.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1323.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1324.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1325.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1326.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1329.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers133.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1330.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1332.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1334.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1335.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1337.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1339.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers134.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1340.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1341.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1342.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1343.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1344.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1345.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1347.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1348.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1349.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers135.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1350.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1352.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1353.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1354.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1355.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1356.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1357.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1358.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1359.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers136.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1360.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1361.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1362.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1363.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1364.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1365.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1366.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1368.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1369.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers137.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1373.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1374.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1375.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1376.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1377.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1379.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers138.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1380.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1382.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1383.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1385.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1386.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1387.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1388.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1389.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers139.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1390.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1391.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1393.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1394.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1395.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1396.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1398.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1399.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers14.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers140.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1400.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1401.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1403.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1404.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1405.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1406.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1407.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1408.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers141.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1410.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1411.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1412.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1413.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1415.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1417.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1418.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers142.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1420.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1423.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1424.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1425.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1426.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1427.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1429.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers143.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1430.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1431.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1432.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1433.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1436.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1437.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1438.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1439.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1440.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1441.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1442.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1443.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1444.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1446.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1447.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1448.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers145.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1450.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1451.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1453.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1454.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1455.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1456.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1457.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1459.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers146.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1460.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1461.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1462.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1464.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1465.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1466.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1467.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1468.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1469.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers147.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1470.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1471.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1473.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1474.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1476.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1477.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers148.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1480.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1481.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1483.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1484.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1485.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1486.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1487.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1489.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers149.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1490.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1491.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1493.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1494.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1495.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1497.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1499.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers15.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers150.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1500.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1501.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1503.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1504.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1505.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1506.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers151.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1510.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1511.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1512.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1513.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1514.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1515.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1516.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1518.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1519.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers152.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1520.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1522.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1524.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1526.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1527.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1529.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers153.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1530.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1531.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1533.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1535.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1538.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1539.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1540.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1541.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1543.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1544.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1545.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1546.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1547.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1548.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1549.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers155.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1550.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1551.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1552.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1553.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1554.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1555.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1556.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1558.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1559.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1562.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1563.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1564.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1565.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1566.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1567.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1569.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers157.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1570.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1571.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1572.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1573.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1574.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1575.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1577.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1579.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers158.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1580.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1581.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1582.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1583.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1584.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1585.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1587.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1589.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1590.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1591.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1592.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1593.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1594.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1595.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1596.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1597.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1598.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1599.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers160.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1601.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1602.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1603.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1604.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1605.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1608.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1609.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers161.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1611.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1613.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1614.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1615.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1616.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1617.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1618.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1619.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1620.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1622.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1623.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1624.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1625.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1626.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1627.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1628.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1629.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers163.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1630.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1631.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1633.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1634.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1635.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1636.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1637.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1639.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers164.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1640.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1641.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1642.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1643.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1645.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1648.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1649.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1650.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1651.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1652.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1653.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1654.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1655.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1657.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers166.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1660.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1661.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1662.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1663.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1664.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1665.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1667.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1668.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1669.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1670.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1671.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1672.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1673.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1675.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1676.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1677.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1678.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers168.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1680.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1682.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1683.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1684.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1688.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1689.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers169.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1690.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1691.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1692.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1693.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1694.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1695.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1696.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1698.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1699.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers17.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers170.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1700.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1701.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1702.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1703.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1704.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1705.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1707.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1708.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers1709.xml
#   inflating: /content/dataset/dataset/labels/train/hard_hat_workers171.xml
# ...
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4514.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4518.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4519.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4524.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4527.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4528.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4532.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4533.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4540.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4545.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4548.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4549.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4558.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers456.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers457.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4571.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4574.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers458.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4586.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4588.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers46.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4602.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4608.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4609.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4619.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers462.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers463.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4632.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers464.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4646.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4647.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4650.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4651.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4654.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4658.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4665.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4667.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4668.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4681.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4682.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4693.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers47.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4704.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4706.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4707.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4723.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4731.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4735.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4736.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4753.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4755.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4761.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4763.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers477.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4771.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4779.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4781.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4787.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4788.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers479.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4806.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers482.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4825.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4826.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4827.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4828.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4829.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers483.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4830.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4831.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4836.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4851.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4860.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4868.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4878.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4882.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4890.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4894.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers49.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers491.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4921.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4923.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4941.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4951.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4954.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4961.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4963.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4968.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4972.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4980.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4994.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers4995.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers5.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers506.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers510.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers515.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers529.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers53.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers530.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers533.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers537.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers550.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers552.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers554.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers558.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers566.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers567.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers570.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers571.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers58.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers59.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers601.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers603.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers608.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers621.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers622.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers627.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers628.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers634.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers643.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers645.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers650.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers652.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers660.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers661.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers664.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers670.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers679.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers681.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers684.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers685.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers686.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers696.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers697.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers699.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers7.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers704.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers705.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers71.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers711.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers714.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers716.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers720.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers721.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers73.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers735.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers739.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers742.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers746.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers749.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers750.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers755.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers76.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers765.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers766.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers768.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers773.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers781.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers783.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers79.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers791.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers793.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers794.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers795.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers805.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers816.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers819.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers820.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers828.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers829.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers833.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers842.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers843.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers847.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers853.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers856.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers857.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers86.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers860.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers863.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers871.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers874.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers875.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers876.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers879.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers882.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers889.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers89.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers891.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers896.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers899.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers901.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers902.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers907.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers910.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers924.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers925.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers927.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers93.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers931.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers938.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers944.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers947.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers958.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers969.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers970.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers977.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers982.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers990.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers995.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers996.xml
#   inflating: /content/dataset/dataset/labels/val/hard_hat_workers998.xml

# %%
data_config = {
    'train': '/content/dataset/dataset/images/train',
    'val': '/content/dataset/dataset/images/val',
    'nc': 1,  # Number of classes
    'names': ['helmet']  # Class names
}

# %%
# Create a dataset.yaml file
dataset_yaml = """
train: /content/dataset/dataset/images/train
val: /content/dataset/dataset/images/val
nc: 1  # Number of classes
names: ['helmet']  # Class names
"""
with open('dataset.yaml', 'w') as f:
    f.write(dataset_yaml)

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17265, done.
# remote: Counting objects: 100% (186/186), done.
# remote: Compressing objects: 100% (126/126), done.
# remote: Total 17265 (delta 107), reused 60 (delta 60), pack-reused 17079 (from 2)
# Receiving objects: 100% (17265/17265), 15.92 MiB | 24.52 MiB/s, done.
# Resolving deltas: 100% (11808/11808), done.

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: gitpython>=3.1.30 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 5)) (3.1.44)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 6)) (3.10.0)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 7)) (1.26.4)
# Requirement already satisfied: opencv-python>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 8)) (4.10.0.84)
# Requirement already satisfied: pillow>=10.3.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 9)) (11.1.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 10)) (5.9.5)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 11)) (6.0.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 12)) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 13)) (1.13.1)
# Collecting thop>=0.1.1 (from -r requirements.txt (line 14))
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 15)) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 16)) (0.20.1+cu121)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 17)) (4.67.1)
# Requirement already satisfied: ultralytics>=8.2.34 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 18)) (8.3.67)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 27)) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 28)) (0.13.2)
# Requirement already satisfied: setuptools>=70.0.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 42)) (75.1.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython>=3.1.30->-r requirements.txt (line 5)) (4.0.12)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (4.55.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (2024.12.14)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->-r requirements.txt (line 15)) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->-r requirements.txt (line 15)) (1.3.0)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics>=8.2.34->-r requirements.txt (line 18)) (9.0.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics>=8.2.34->-r requirements.txt (line 18)) (2.0.14)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2025.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r requirements.txt (line 5)) (5.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->-r requirements.txt (line 15)) (3.0.2)
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Installing collected packages: thop
# Successfully installed thop-0.1.1.post2209072238

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data dataset.yaml --weights yolov5s.pt
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-01-24 18:00:18.348725: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-24 18:00:18.373450: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-24 18:00:18.380658: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: Currently logged in as: rachid-elbacha23 (rachid-elbacha23-sultan-moulay-slimane-university). Use `wandb login --relogin` to force relogin
# train: weights=yolov5s.pt, cfg=, data=dataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# Traceback (most recent call last):
#   File "/content/yolov5/train.py", line 986, in <module>
#     main(opt)
#   File "/content/yolov5/train.py", line 656, in main
#     check_file(opt.data),
#     ^^^^^^^^^^^^^^^^^^^^
#   File "/content/yolov5/utils/general.py", line 506, in check_file
#     assert len(files), f"File not found: {file}"  # assert file was found
#            ^^^^^^^^^^
# AssertionError: File not found: dataset.yaml

# %%
# Create and save the dataset.yaml file
dataset_yaml = """
train: /content/dataset/dataset/images/train
val: /content/dataset/dataset/images/val

nc: 1  # Number of classes
names: ['helmet']  # Class names
"""

with open('dataset.yaml', 'w') as f:
    f.write(dataset_yaml)

print("dataset.yaml created successfully!")
# Out:
# dataset.yaml created successfully!

# %%
# !wandb login
# Out:
# wandb: Currently logged in as: rachid-elbacha23 (rachid-elbacha23-sultan-moulay-slimane-university). Use `wandb login --relogin` to force relogin

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data dataset.yaml --weights yolov5s.pt
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-01-24 18:01:16.191119: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-24 18:01:16.230922: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-24 18:01:16.243082: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: Currently logged in as: rachid-elbacha23 (rachid-elbacha23-sultan-moulay-slimane-university). Use `wandb login --relogin` to force relogin
# train: weights=yolov5s.pt, cfg=, data=dataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-397-gde62f93c Python-3.11.11 torch-2.5.1+cu121 CPU
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Tracking run with wandb version 0.19.4
# wandb: Run data is saved locally in /content/yolov5/wandb/run-20250124_180119-g8x1evyj
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run honest-plasma-1
# wandb: ⭐️ View project at https://wandb.ai/rachid-elbacha23-sultan-moulay-slimane-university/YOLOv5
# wandb: 🚀 View run at https://wandb.ai/rachid-elbacha23-sultan-moulay-slimane-university/YOLOv5/runs/g8x1evyj
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 62.3MB/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100% 14.1M/14.1M [00:00<00:00, 240MB/s]
#
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7022326 parameters, 7022326 gradients, 15.9 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/dataset/dataset/labels/train... 0 images, 4000 backgrounds, 0 corrupt: 100% 4000/4000 [00:05<00:00, 784.11it/s]
# train: WARNING ⚠️ No labels found in /content/dataset/dataset/labels/train.cache. See https://docs.ultralytics.com/yolov5/tutorials/train_custom_data
# train: New cache created: /content/dataset/dataset/labels/train.cache
# Traceback (most recent call last):
#   File "/content/yolov5/train.py", line 986, in <module>
#     main(opt)
#   File "/content/yolov5/train.py", line 688, in main
#     train(opt.hyp, opt, device, callbacks)
#   File "/content/yolov5/train.py", line 285, in train
#     train_loader, dataset = create_dataloader(
#                             ^^^^^^^^^^^^^^^^^^
#   File "/content/yolov5/utils/dataloaders.py", line 184, in create_dataloader
#     dataset = LoadImagesAndLabels(
#               ^^^^^^^^^^^^^^^^^^^^
#   File "/content/yolov5/utils/dataloaders.py", line 611, in __init__
#     assert nf > 0 or not augment, f"{prefix}No labels found in {cache_path}, can not start training. {HELP_URL}"
#            ^^^^^^^^^^^^^^^^^^^^^
# AssertionError: train: No labels found in /content/dataset/dataset/labels/train.cache, can not start training. See https://docs.ultralytics.com/yolov5/tutorials/train_custom_data
# wandb:
# wandb: 🚀 View run honest-plasma-1 at: https://wandb.ai/rachid-elbacha23-sultan-moulay-slimane-university/YOLOv5/runs/g8x1evyj
# wandb: Find logs at: wandb/run-20250124_180119-g8x1evyj/logs

# %%
# !rm -rf /content/dataset/labels/train.cache

# %% [markdown]
# # Setup
#
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/pyproject.toml) and check software and hardware.
#
# [![PyPI - Version](https://img.shields.io/pypi/v/ultralytics?logo=pypi&logoColor=white)](https://pypi.org/project/ultralytics/) [![Downloads](https://static.pepy.tech/badge/ultralytics)](https://www.pepy.tech/projects/ultralytics) [![PyPI - Python Version](https://img.shields.io/pypi/pyversions/ultralytics?logo=python&logoColor=gold)](https://pypi.org/project/ultralytics/)

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data dataset.yaml --weights yolov5s.pt
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-01-24 18:04:28.437267: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-24 18:04:28.477260: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-24 18:04:28.489765: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: Currently logged in as: rachid-elbacha23 (rachid-elbacha23-sultan-moulay-slimane-university). Use `wandb login --relogin` to force relogin
# train: weights=yolov5s.pt, cfg=, data=dataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-397-gde62f93c Python-3.11.11 torch-2.5.1+cu121 CPU
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Tracking run with wandb version 0.19.4
# wandb: Run data is saved locally in /content/yolov5/wandb/run-20250124_180431-pkeot5tq
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run smooth-terrain-2
# wandb: ⭐️ View project at https://wandb.ai/rachid-elbacha23-sultan-moulay-slimane-university/YOLOv5
# wandb: 🚀 View run at https://wandb.ai/rachid-elbacha23-sultan-moulay-slimane-university/YOLOv5/runs/pkeot5tq
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7022326 parameters, 7022326 gradients, 15.9 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/dataset/dataset/labels/train.cache... 0 images, 4000 backgrounds, 0 corrupt: 100% 4000/4000 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "/content/yolov5/train.py", line 986, in <module>
#     main(opt)
#   File "/content/yolov5/train.py", line 688, in main
#     train(opt.hyp, opt, device, callbacks)
#   File "/content/yolov5/train.py", line 285, in train
#     train_loader, dataset = create_dataloader(
#                             ^^^^^^^^^^^^^^^^^^
#   File "/content/yolov5/utils/dataloaders.py", line 184, in create_dataloader
#     dataset = LoadImagesAndLabels(
#               ^^^^^^^^^^^^^^^^^^^^
#   File "/content/yolov5/utils/dataloaders.py", line 611, in __init__
#     assert nf > 0 or not augment, f"{prefix}No labels found in {cache_path}, can not start training. {HELP_URL}"
#            ^^^^^^^^^^^^^^^^^^^^^
# AssertionError: train: No labels found in /content/dataset/dataset/labels/train.cache, can not start training. See https://docs.ultralytics.com/yolov5/tutorials/train_custom_data
# wandb:
# wandb: 🚀 View run smooth-terrain-2 at: https://wandb.ai/rachid-elbacha23-sultan-moulay-slimane-university/YOLOv5/runs/pkeot5tq
# wandb: Find logs at: wandb/run-20250124_180431-pkeot5tq/logs

# %% [markdown]
# # 1. Predict
#
# YOLO11 may be used directly in the Command Line Interface (CLI) with a `yolo` command for a variety of tasks and modes and accepts additional arguments, i.e. `imgsz=640`. See a full list of available `yolo` [arguments](https://docs.ultralytics.com/usage/cfg/) and other details in the [YOLO11 Predict Docs](https://docs.ultralytics.com/modes/train/).

# %%
# Run inference on an image with YOLO11n
# !yolo predict model=yolo11n.pt source='https://ultralytics.com/images/zidane.jpg'
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100% 5.35M/5.35M [00:00<00:00, 72.7MB/s]
# Ultralytics 8.3.2 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11n summary (fused): 238 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# Downloading https://ultralytics.com/images/zidane.jpg to 'zidane.jpg'...
# 100% 49.2k/49.2k [00:00<00:00, 5.37MB/s]
# image 1/1 /content/zidane.jpg: 384x640 2 persons, 1 tie, 63.4ms
# Speed: 14.5ms preprocess, 63.4ms inference, 820.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/212889447-69e5bdf1-5800-4e29-835e-2ed2336dede2.jpg" width="600">

# %% [markdown]
# # 2. Val
# Validate a model's accuracy on the [COCO](https://docs.ultralytics.com/datasets/detect/coco/) dataset's `val` or `test` splits. The latest YOLO11 [models](https://github.com/ultralytics/ultralytics#models) are downloaded automatically the first time they are used. See [YOLO11 Val Docs](https://docs.ultralytics.com/modes/val/) for more information.

# %%
# Download COCO val
import torch
torch.hub.download_url_to_file('https://ultralytics.com/assets/coco2017val.zip', 'tmp.zip')  # download (780M - 5000 images)
# !unzip -q tmp.zip -d datasets && rm tmp.zip  # unzip

# %%
# Validate YOLO11n on COCO8 val
# !yolo val model=yolo11n.pt data=coco8.yaml
# Out:
# Ultralytics 8.3.2 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11n summary (fused): 238 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# Dataset 'coco8.yaml' images not found ⚠️, missing path '/content/datasets/coco8/images/val'
# Downloading https://ultralytics.com/assets/coco8.zip to '/content/datasets/coco8.zip'...
# 100% 433k/433k [00:00<00:00, 15.8MB/s]
# Unzipping /content/datasets/coco8.zip to /content/datasets/coco8...: 100% 25/25 [00:00<00:00, 1188.35file/s]
# Dataset download success ✅ (1.4s), saved to /content/datasets
#
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 17.7MB/s]
# val: Scanning /content/datasets/coco8/labels/val... 4 images, 0 backgrounds, 0 corrupt: 100% 4/4 [00:00<00:00, 142.04it/s]
# val: New cache created: /content/datasets/coco8/labels/val.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:04<00:00,  4.75s/it]
#                    all          4         17       0.57       0.85      0.847      0.632
#                 person          3         10      0.557        0.6      0.585      0.272
#                    dog          1          1      0.548          1      0.995      0.697
#                  horse          1          2      0.531          1      0.995      0.674
#               elephant          1          2      0.371        0.5      0.516      0.256
#               umbrella          1          1      0.569          1      0.995      0.995
#           potted plant          1          1      0.847          1      0.995      0.895
# Speed: 1.0ms preprocess, 73.8ms inference, 0.0ms loss, 561.4ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# # 3. Train
#
# <p align=""><a href="https://ultralytics.com/hub"><img width="1000" src="https://github.com/ultralytics/assets/raw/main/yolov8/banner-integrations.png"/></a></p>
#
# Train YOLO11 on [Detect](https://docs.ultralytics.com/tasks/detect/), [Segment](https://docs.ultralytics.com/tasks/segment/), [Classify](https://docs.ultralytics.com/tasks/classify/) and [Pose](https://docs.ultralytics.com/tasks/pose/) datasets. See [YOLO11 Train Docs](https://docs.ultralytics.com/modes/train/) for more information.

# %%
#@title Select YOLO11 🚀 logger {run: 'auto'}
logger = 'Comet' #@param ['Comet', 'TensorBoard']

if logger == 'Comet':
  # %pip install -q comet_ml
  import comet_ml; comet_ml.init()
elif logger == 'TensorBoard':
  # %load_ext tensorboard
  # %tensorboard --logdir .

# %%
# Train YOLO11n on COCO8 for 3 epochs
# !yolo train model=yolo11n.pt data=coco8.yaml epochs=3 imgsz=640
# Out:
# Ultralytics 8.3.2 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# engine/trainer: task=detect, mode=train, model=yolo11n.pt, data=coco8.yaml, epochs=3, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train3, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    464912  ultralytics.nn.modules.head.Detect           [80, [64, 128, 256]]
# YOLO11n summary: 319 layers, 2,624,080 parameters, 2,624,064 gradients, 6.6 GFLOPs
#
# Transferred 499/499 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLO11n...
# AMP: checks passed ✅
# train: Scanning /content/datasets/coco8/labels/train.cache... 4 images, 0 backgrounds, 0 corrupt: 100% 4/4 [00:00<?, ?it/s]
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/datasets/coco8/labels/val.cache... 4 images, 0 backgrounds, 0 corrupt: 100% 4/4 [00:00<?, ?it/s]
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000119, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/train
# Starting training for 3 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/3     0.719G      1.004      3.249      1.367         30        640: 100% 1/1 [00:00<00:00,  1.16it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  5.07it/s]
#                    all          4         17       0.58       0.85      0.849      0.631
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/3     0.715G       1.31      4.043      1.603         35        640: 100% 1/1 [00:00<00:00,  6.88it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  9.08it/s]
#                    all          4         17      0.581       0.85      0.851       0.63
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         3/3     0.692G      1.134      3.174      1.599         18        640: 100% 1/1 [00:00<00:00,  6.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 11.60it/s]
#                    all          4         17      0.582       0.85      0.855      0.632
#
# 3 epochs completed in 0.003 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 5.5MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 5.5MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.2 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11n summary (fused): 238 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 23.42it/s]
#                    all          4         17      0.579       0.85      0.855      0.615
#                 person          3         10      0.579        0.6      0.623      0.268
#                    dog          1          1      0.549          1      0.995      0.697
#                  horse          1          2      0.553          1      0.995      0.675
#               elephant          1          2      0.364        0.5      0.528      0.261
#               umbrella          1          1      0.571          1      0.995      0.895
#           potted plant          1          1      0.857          1      0.995      0.895
# Speed: 0.2ms preprocess, 4.3ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# # 4. Export
#
# Export a YOLO11 model to any supported format below with the `format` argument, i.e. `format=onnx`. See [YOLO11 Export Docs](https://docs.ultralytics.com/modes/export/) for more information.
#
# - 💡 ProTip: Export to [ONNX](https://docs.ultralytics.com/integrations/onnx/) or [OpenVINO](https://docs.ultralytics.com/integrations/openvino/) for up to 3x CPU speedup.
# - 💡 ProTip: Export to [TensorRT](https://docs.ultralytics.com/integrations/tensorrt/) for up to 5x GPU speedup.
#
# | Format                                                                   | `format` Argument | Model                     | Metadata | Arguments                                                            |
# |--------------------------------------------------------------------------|-------------------|---------------------------|----------|----------------------------------------------------------------------|
# | [PyTorch](https://pytorch.org/)                                          | -                 | `yolo11n.pt`              | ✅        | -                                                                    |
# | [TorchScript](https://docs.ultralytics.com/integrations/torchscript)     | `torchscript`     | `yolo11n.torchscript`     | ✅        | `imgsz`, `optimize`, `batch`                                         |
# | [ONNX](https://docs.ultralytics.com/integrations/onnx)                   | `onnx`            | `yolo11n.onnx`            | ✅        | `imgsz`, `half`, `dynamic`, `simplify`, `opset`, `batch`             |
# | [OpenVINO](https://docs.ultralytics.com/integrations/openvino)           | `openvino`        | `yolo11n_openvino_model/` | ✅        | `imgsz`, `half`, `dynamic`, `int8`, `batch`                          |
# | [TensorRT](https://docs.ultralytics.com/integrations/tensorrt)           | `engine`          | `yolo11n.engine`          | ✅        | `imgsz`, `half`, `dynamic`, `simplify`, `workspace`, `int8`, `batch` |
# | [CoreML](https://docs.ultralytics.com/integrations/coreml)               | `coreml`          | `yolo11n.mlpackage`       | ✅        | `imgsz`, `half`, `int8`, `nms`, `batch`                              |
# | [TF SavedModel](https://docs.ultralytics.com/integrations/tf-savedmodel) | `saved_model`     | `yolo11n_saved_model/`    | ✅        | `imgsz`, `keras`, `int8`, `batch`                                    |
# | [TF GraphDef](https://docs.ultralytics.com/integrations/tf-graphdef)     | `pb`              | `yolo11n.pb`              | ❌        | `imgsz`, `batch`                                                     |
# | [TF Lite](https://docs.ultralytics.com/integrations/tflite)              | `tflite`          | `yolo11n.tflite`          | ✅        | `imgsz`, `half`, `int8`, `batch`                                     |
# | [TF Edge TPU](https://docs.ultralytics.com/integrations/edge-tpu)        | `edgetpu`         | `yolo11n_edgetpu.tflite`  | ✅        | `imgsz`                                                              |
# | [TF.js](https://docs.ultralytics.com/integrations/tfjs)                  | `tfjs`            | `yolo11n_web_model/`      | ✅        | `imgsz`, `half`, `int8`, `batch`                                     |
# | [PaddlePaddle](https://docs.ultralytics.com/integrations/paddlepaddle)   | `paddle`          | `yolo11n_paddle_model/`   | ✅        | `imgsz`, `batch`                                                     |
# | [MNN](https://docs.ultralytics.com/integrations/mnn)                     | `mnn`             | `yolo11n.mnn`             | ✅        | `imgsz`, `batch`, `int8`, `half`                                     |
# | [NCNN](https://docs.ultralytics.com/integrations/ncnn)                   | `ncnn`            | `yolo11n_ncnn_model/`     | ✅        | `imgsz`, `half`, `batch`                                             |
# | [IMX500](https://docs.ultralytics.com/integrations/sony-imx500)          | `imx`             | `yolov8n_imx_model/`      | ✅        | `imgsz`, `int8`                                                      |
# | [RKNN](https://docs.ultralytics.com/integrations/rockchip-rknn)          | `rknn`            | `yolo11n_rknn_model/`     | ✅        | `imgsz`, `batch`, `name`                                             |

# %%
# !yolo export model=yolo11n.pt format=torchscript
# Out:
# Ultralytics 8.3.2 🚀 Python-3.10.12 torch-2.4.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 238 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# PyTorch: starting from 'yolo11n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (5.4 MB)
#
# TorchScript: starting export with torch 2.4.1+cu121...
# TorchScript: export success ✅ 2.4s, saved as 'yolo11n.torchscript' (10.5 MB)
#
# Export complete (4.2s)
# Results saved to /content
# Predict:         yolo predict task=detect model=yolo11n.torchscript imgsz=640
# Validate:        yolo val task=detect model=yolo11n.torchscript imgsz=640 data=coco.yaml
# Visualize:       https://netron.app
# 💡 Learn more at https://docs.ultralytics.com/modes/export

# %% [markdown]
# # 5. Python Usage
#
# YOLO11 was reimagined using Python-first principles for the most seamless Python YOLO experience yet. YOLO11 models can be loaded from a trained checkpoint or created from scratch. Then methods are used to train, val, predict, and export the model. See detailed Python usage examples in the [YOLO11 Python Docs](https://docs.ultralytics.com/usage/python/).

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolo11n.yaml')  # build a new model from scratch
model = YOLO('yolo11n.pt')  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data='coco8.yaml', epochs=3)  # train the model
results = model.val()  # evaluate model performance on the validation set
results = model('https://ultralytics.com/images/bus.jpg')  # predict on an image
results = model.export(format='onnx')  # export the model to ONNX format

# %% [markdown]
# # 6. Tasks
#
# YOLO11 can train, val, predict and export models for the most common tasks in vision AI: [Detect](https://docs.ultralytics.com/tasks/detect/), [Segment](https://docs.ultralytics.com/tasks/segment/), [Classify](https://docs.ultralytics.com/tasks/classify/) and [Pose](https://docs.ultralytics.com/tasks/pose/). See [YOLO11 Tasks Docs](https://docs.ultralytics.com/tasks/) for more information.
#
# <br><img width="1024" src="https://raw.githubusercontent.com/ultralytics/assets/main/im/banner-tasks.png">

# %% [markdown]
# ## 1. Detection
#
# YOLO11 _detection_ models have no suffix and are the default YOLO11 models, i.e. `yolo11n.pt` and are pretrained on COCO. See [Detection Docs](https://docs.ultralytics.com/tasks/detect/) for full details.

# %%
# Load YOLO11n, train it on COCO128 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolo11n.pt')  # load a pretrained YOLO detection model
model.train(data='coco8.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# ## 2. Segmentation
#
# YOLO11 _segmentation_ models use the `-seg` suffix, i.e. `yolo11n-seg.pt` and are pretrained on COCO. See [Segmentation Docs](https://docs.ultralytics.com/tasks/segment/) for full details.

# %%
# Load YOLO11n-seg, train it on COCO128-seg for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolo11n-seg.pt')  # load a pretrained YOLO segmentation model
model.train(data='coco8-seg.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# ## 3. Classification
#
# YOLO11 _classification_ models use the `-cls` suffix, i.e. `yolo11n-cls.pt` and are pretrained on ImageNet. See [Classification Docs](https://docs.ultralytics.com/tasks/classify/) for full details.

# %%
# Load YOLO11n-cls, train it on mnist160 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolo11n-cls.pt')  # load a pretrained YOLO classification model
model.train(data='mnist160', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# ## 4. Pose
#
# YOLO11 _pose_ models use the `-pose` suffix, i.e. `yolo11n-pose.pt` and are pretrained on COCO Keypoints. See [Pose Docs](https://docs.ultralytics.com/tasks/pose/) for full details.

# %%
# Load YOLO11n-pose, train it on COCO8-pose for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolo11n-pose.pt')  # load a pretrained YOLO pose model
model.train(data='coco8-pose.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# ## 4. Oriented Bounding Boxes (OBB)
#
# YOLO11 _OBB_ models use the `-obb` suffix, i.e. `yolo11n-obb.pt` and are pretrained on the DOTA dataset. See [OBB Docs](https://docs.ultralytics.com/tasks/obb/) for full details.

# %%
# Load YOLO11n-obb, train it on DOTA8 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolo11n-obb.pt')  # load a pretrained YOLO OBB model
model.train(data='dota8.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/boats.jpg')  # predict on an image

# %% [markdown]
# # Appendix
#
# Additional content below.

# %%
# Pip install from source
# !pip install git+https://github.com/ultralytics/ultralytics@main

# %%
# Git clone and run tests on updates branch
# !git clone https://github.com/ultralytics/ultralytics -b main
# %pip install -qe ultralytics

# %%
# Run tests (Git clone only)
# !pytest ultralytics/tests

# %%
# Validate multiple models
for x in 'nsmlx':
  # !yolo val model=yolo11{x}.pt data=coco.yaml
